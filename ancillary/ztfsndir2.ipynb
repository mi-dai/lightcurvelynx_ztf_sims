# %%
# from utils.ztfdata_utils import parse_all_lightcurves
# parse_all_lightcurves(datadir='ztfsniadr2/')

# %%
import matplotlib.pyplot as plt
from nested_pandas import read_parquet

# %%
ndf = read_parquet('data/ztfsniadr2.parquet')

# %%
ndf.redshift.hist(bins=20)
# Out:
# <Axes: >

# %%
ndf
# Out:
#            ztfname  redshift  redshift_err  source            t0        x0  \
# 0     ZTF17aadlxmv  0.062019      0.000013   z_gal  58878.085277  0.001126
# 1     ZTF18aaadqua  0.078672      0.002807  z_snid  58130.778798  0.000845
# ...            ...       ...           ...     ...           ...       ...
# 3626  ZTF19acdtmwh  0.069910      0.000015   z_gal  58774.273070  0.000468
# 3627  ZTF20aatvdwr  0.036318      0.000011   z_gal  58945.121621  0.005931
#
#             x1         c     t0_err    x0_err  ...          ra        dec  \
# 0     0.459966  0.062074   0.219280  0.000037  ...  127.448018  33.906536
# 1     4.999999 -0.392734  14.743977  0.000103  ...   26.798708  18.798611
# ...        ...       ...        ...       ...  ...         ...        ...
# 3626 -0.264331  0.199896   0.231173  0.000026  ...  145.292578  24.022865
# 3627  2.264104  0.136763   0.302343  0.000230  ...  211.826080  -5.127130
#
# ...
